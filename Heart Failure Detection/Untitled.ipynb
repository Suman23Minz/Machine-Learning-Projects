# %%
# Importing the numpy and pandas library into the program.
import numpy as np
import pandas as pd

# %%
# Loading the dataset.
df = pd.read_csv('heartfailure_database.csv')

# %%
# EXPLORING THE DATASET...

# %%
# Returns the total number of rows and columns in the dataset.
df.shape
# Out:
# (918, 12)

# %%
# Returns the columns(Attributes) in the dataset.
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Returns the datatypes for each columns(Attribute).
df.dtypes
# Out:
# Age                 int64
# Sex                 int64
# ChestPainType       int64
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG          int64
# MaxHR               int64
# ExerciseAngina      int64
# Oldpeak           float64
# ST_Slope            int64
# HeartDisease        int64
# dtype: object

# %%
# Returns the first x number of rows using head(x), default is 5.
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140          289          0           0
# 1   49    1              1        160          180          0           0
# 2   37    0              0        130          283          0           1
# 3   48    1              2        138          214          0           0
# 4   54    0              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %%
# Returns the last x number of columns using tail(x), default is 5.
df.tail()
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 913   45    0              3        110          264          0           0
# 914   68    0              2        144          193          1           0
# 915   57    0              2        130          131          0           0
# 916   57    1              0        130          236          0           2
# 917   38    0              1        138          175          0           0
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 913    132               0      1.2         1             1
# 914    141               0      3.4         1             1
# 915    115               1      1.2         1             1
# 916    174               0      0.0         1             1
# 917    173               0      0.0         0             0

# %%
# Returns true if any column(Attribute) field contains NULL values, else false.
df.isnull().any()
# Out:
# Age               False
# Sex               False
# ChestPainType     False
# RestingBP         False
# Cholesterol       False
# FastingBS         False
# RestingECG        False
# MaxHR             False
# ExerciseAngina    False
# Oldpeak           False
# ST_Slope          False
# HeartDisease      False
# dtype: bool

# %%
# Returns the information regarding columns(Attributes).
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 86.2 KB

# %%
# Returns the statistical values of different columns(Attributes).
df.describe()
# Out:
#               Age         Sex  ChestPainType   RestingBP  Cholesterol  \
# count  918.000000  918.000000     918.000000  918.000000   918.000000
# mean    53.510893    0.210240       1.452070  132.396514   198.799564
# std      9.432617    0.407701       0.851832   18.514154   109.384145
# min     28.000000    0.000000       0.000000    0.000000     0.000000
# 25%     47.000000    0.000000       1.000000  120.000000   173.250000
# 50%     54.000000    0.000000       2.000000  130.000000   223.000000
# 75%     60.000000    0.000000       2.000000  140.000000   267.000000
# max     77.000000    1.000000       3.000000  200.000000   603.000000
#
#         FastingBS  RestingECG       MaxHR  ExerciseAngina     Oldpeak  \
# count  918.000000  918.000000  918.000000      918.000000  918.000000
# mean     0.233115    0.603486  136.809368        0.404139    0.887364
# std      0.423046    0.805968   25.460334        0.490992    1.066570
# ...

# %%
# Returns the same as above but the metrix is transposed for better visual understanding.
df.describe().T
# Out:
#                 count        mean         std   min     25%    50%    75%  \
# Age             918.0   53.510893    9.432617  28.0   47.00   54.0   60.0
# Sex             918.0    0.210240    0.407701   0.0    0.00    0.0    0.0
# ChestPainType   918.0    1.452070    0.851832   0.0    1.00    2.0    2.0
# RestingBP       918.0  132.396514   18.514154   0.0  120.00  130.0  140.0
# Cholesterol     918.0  198.799564  109.384145   0.0  173.25  223.0  267.0
# FastingBS       918.0    0.233115    0.423046   0.0    0.00    0.0    0.0
# RestingECG      918.0    0.603486    0.805968   0.0    0.00    0.0    1.0
# MaxHR           918.0  136.809368   25.460334  60.0  120.00  138.0  156.0
# ExerciseAngina  918.0    0.404139    0.490992   0.0    0.00    0.0    1.0
# Oldpeak         918.0    0.887364    1.066570  -2.6    0.00    0.6    1.5
# ST_Slope        918.0    0.638344    0.607056   0.0    0.00    1.0    1.0
# HeartDisease    918.0    0.553377    0.497414   0.0    0.00    1.0    1.0
#
# ...

# %%
# DATA VISUALIZATION...

# %%
# Importing matplotlib a common data visualization library.
import matplotlib.pyplot as plt

# For implementing the cvarious plot in single output.
# %matplotlib inline

# Importing seaborn data visualization library
import seaborn as sns

# %%
# PLotting histograms for the entire dataset.
Fig = plt.figure(figsize = (15, 20))

# Variable ax for axes and holds "get current axes" method
ax = Fig.gca()
chart = df.hist(ax=ax)
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_25432\2943827970.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   chart = df.hist(ax=ax)

# %%
# Visualization to check if the dataset is balanced or not
chart = sns.countplot(x = 'HeartDisease', data = df)

# Adding Labels to the axies.
plt.xlabel('HeartDisease')
plt.ylabel('Count')
# Out:
# C:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\suman\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0, 0.5, 'Count')

# %%
# FEATURE ENGINEERING...

# %%
# Selecting correlated features using Heatmap.

# Get correlation of all the features of the dataset
corr_matrix = df.corr()
top_corr_features = corr_matrix.index

# Plotting the headmap
plt.figure(figsize = (20, 20))
sns.heatmap(data=df[top_corr_features].corr(), annot = True, cmap = 'RdYlGn')
# Out:
# <Axes: >

# %%
# DATA PREPROCESSING...

# %%
dataset = pd.get_dummies(df, columns=['Sex','ChestPainType','FastingBS','RestingECG','ExerciseAngina','ST_Slope'])

# %%
# FEATURE SCALING...

# %%
# Retriving the data from database.
dataset.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak', 'HeartDisease',
#        'Sex_0', 'Sex_1', 'ChestPainType_0', 'ChestPainType_1',
#        'ChestPainType_2', 'ChestPainType_3', 'FastingBS_0', 'FastingBS_1',
#        'RestingECG_0', 'RestingECG_1', 'RestingECG_2', 'ExerciseAngina_0',
#        'ExerciseAngina_1', 'ST_Slope_0', 'ST_Slope_1', 'ST_Slope_2'],
#       dtype='object')

# %%
# Importing StandardScaler object from sklearn library.
from sklearn.preprocessing import StandardScaler
stndSclr = StandardScaler()

# Identifying column to scale.
column_to_scale = ['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']

# Standardising the selected column, fit_transform method is applied.
dataset[column_to_scale] = stndSclr.fit_transform(dataset[column_to_scale])

# %%
# Returns the first x number of rows using head(x), default is 5.
dataset.head()
# Out:
#         Age  RestingBP  Cholesterol     MaxHR   Oldpeak  HeartDisease  Sex_0  \
# 0 -1.433140   0.410909     0.825070  1.382928 -0.832432             0   True
# 1 -0.478484   1.491752    -0.171961  0.754157  0.105664             1  False
# 2 -1.751359  -0.129513     0.770188 -1.525138 -0.832432             0   True
# 3 -0.584556   0.302825     0.139040 -1.132156  0.574711             1  False
# 4  0.051881   0.951331    -0.034755 -0.581981 -0.832432             0   True
#
#    Sex_1  ChestPainType_0  ChestPainType_1  ...  FastingBS_0  FastingBS_1  \
# 0  False             True            False  ...         True        False
# 1   True            False             True  ...         True        False
# 2  False             True            False  ...         True        False
# 3   True            False            False  ...         True        False
# 4  False            False             True  ...         True        False
#
# ...

# %%
# Splitting the dataset into dependent and independent features.
X.flags.c_contiguous = dataset.drop('HeartDisease', axis = 1)
y = dataset['HeartDisease']

# %%
# MODEL BUILDING

# %%
# KNeighbors Classifier Model...

# %%
# Importing KNeighborsClassifier from sklearn library.
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
# Initializing an empty list.
forest_scores = []

# Finding the best accuracy for knn algorithm using cross_val_score
for i in range(10, 101, 10):
    forest_classifier = RandomForestClassifier(n_estimators=i)
    cvs_scores = cross_val_score(forest_classifier, X, y, cv=5)
    forest_scores.append(round(cvs_scores.mean(),3))

# %%
# Plotting the results of knn_scores
plt.figure(figsize=(20,15))
plt.plot([k for k in range(10, 101, 10)], forest_scores, color = 'red')
for i in range(1,11):
    plt.text(i*10, forest_scores[i-1], (i*10, forest_scores[i-1]))
plt.xticks([i for i in range(10, 101, 10)])
plt.xlabel('Number of Estimators (N)')
plt.ylabel('Scores')
plt.title('Random Forest Classifier scores for different N values')
# Out:
# Text(0.5, 1.0, 'Random Forest Classifier scores for different N values')

# %%
# Training the random forest classifier model with n value as 90
forest_classifier = RandomForestClassifier(n_estimators=90)
cvs_scores = cross_val_score(forest_classifier, X, y, cv=5)
print("Random Forest Classifier Accuracy with n_estimators=90 is: {}%".format(round(cvs_scores.mean(), 4)*100))
# Out:
# Random Forest Classifier Accuracy with n_estimators=90 is: 83.0%
